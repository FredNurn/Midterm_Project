# %%
import requests 
from bs4 import BeautifulSoup

# %%
url = "https://www.finanzen.net/index/dax" 
page = requests.get(url)
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="de" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link crossorigin="" href="//c.finanzen.net" rel="preconnect"/>
#   <link crossorigin="" href="//images.finanzen.net" rel="preconnect"/>
#   <link crossorigin="" href="//styles.finanzen.net" rel="preconnect"/>
#   <link crossorigin="" href="//scripts.finanzen.net" rel="preconnect"/>
#   <link crossorigin="" href="//mdsngpush.finanzen.net" rel="preconnect"/>
#   <link as="script" href="https://cdn.privacy-mgmt.com/wrapperMessagingWithoutDetection.js" rel="preload"/>
#   <link as="font" crossorigin="" href="https://styles.finanzen.net/Content/Styles/dist/fonts/OpenSans-Bold.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="" href="https://styles.finanzen.net/Content/Styles/dist/fonts/OpenSans-Regular.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="" href="https://styles.finanzen.net/Content/Styles/dist/fonts/OpenSans-SemiBold.woff" rel="preload" type="font/woff"/>
#   <link crossorigin="" href="//www.asadcdn.com" rel="preconnect"/>
#   <link href="//cdn1.smartadserver.com" rel="dns-prefetch"/>
#   <link href="//ww251.smartadserver.com" rel="dns-prefetch"/>
#   <link href="//adtechnology.mediaimpact.de" rel="dns-prefetch"/>
#   <link href="//ib.adnxs.com" rel="dns-prefetch"/>
#   <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>
#   <link href="//static.criteo.net" rel="dns-prefetch"/>
#   <link href="//cdnjs.cloudflare.com" rel="dns-prefetch"/>
#   <link href="//d.df-srv.de" rel="dns-prefetch"/>
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//www.gstatic.com" rel="dns-prefetch"/>
#   <link href="//contributor.google.com" rel="dns-prefetch"/>
#   <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//www.googleadservices.com" rel="dns-prefetch"/>
#   <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#   <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="//script.ioam.de" rel="preconnect"/>
#   <link href="//widgets.outbrain.com" rel="dns-prefetch"/>
#   <link href="//a.optmnstr.com" rel="dns-prefetch"/>
#   <link href="//api.optmnstr.com" rel="dns-prefetch"/>
#   <meta content="finanzen.net GmbH" name="Publisher"/>
#   <meta content="finanzen.net GmbH" name="Copyright"/>
#   <meta content="Finanzen" name="page-topic"/>
#   <meta content="Kommerzielle Homepage" name="page-type"/>
#   <meta content="Alle" name="audience"/>
#   <meta content="#093967" name="theme-color"/>
#   <title>
#    DAX heute aktuell | Index, Stand und Kurs | finanzen.net
#   </title>
#   <meta content="DAX heute aktuell | Index, Stand und Kurs | finanzen.net" name="title"/>
#   <meta content="DAX heute aktuell | Index, Stand und Kurs | finanzen.net" property="og:title"/>
#   <meta content="DAX heute (846900,DE0008469008): aktueller DAX Kurs und historische Entwicklung. Hier finden Sie Aktien, Kurse, Charts, Listen und News." name="description"/>
#   <meta content="DAX heute (846900,DE0008469008): aktueller DAX Kurs und historische Entwicklung. Hier finden Sie Aktien, Kurse, Charts, Listen und News." property="og:description"/>
#   <meta content="INDEX,FOLLOW" name="Robots"/>
#   <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
#   <link href="https://www.finanzen.ch/index/dax" hreflang="de-CH" rel="alternate"/>
#   <link href="https://www.finanzen.at/index/dax" hreflang="de-AT" rel="alternate"/>
#   <link href="https://www.finanzen.net/index/dax" hreflang="de-DE" rel="alternate"/>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script>
#    window.getGaConsent = function () {
# 		var match = document.cookie.match(new RegExp('(^| )googleanalytics_consent=([^;]+)'));
# 		if (match) return match[2];
# 	}
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-1858090-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag() { dataLayer.push(arguments); }
#
#     var activatePageView = (window.getGaConsent() === 'active=true');
#
#     if (activatePageView) {
#         gtag('js', new Date());
#
#         gtag('config', 'G-J4WKRJQPHJ', { 'send_page_view': activatePageView });
#         gtag('config', 'G-NHYZMZLPTK', { 'send_page_view': activatePageView });
#         gtag('config', 'UA-1858090-1', { 'send_page_view': activatePageView });
#
#         //commerc.ly CB-428
#         gtag('js', new Date());
#         gtag('config', 'AW-10967047558', { 'send_page_view': activatePageView });
# 	}
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' });
# 		var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-TZL853');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script class="cmp-script" data-cmp-purpose="social" data-cmp-type="facebook" type="text/html">
#    PHNjcmlwdCBhc3luYyBzcmM9Imh0dHBzOi8vY29ubmVjdC5mYWNlYm9vay5uZXQvZW5fVVMvZmJldmVudHMuanMiPjwvc2NyaXB0Pg==
#   </script>
#   <script>
#    window.fbq = function () {
# 		window.fbq.callMethod ? window.fbq.callMethod.apply(window.fbq, arguments) : window.fbq.queue.push(arguments)
# 	};
# 	if (!window._fbq) window._fbq = window.fbq;
# 	window.fbq.push = window.fbq;
# 	window.fbq.loaded = !0;
# 	window.fbq.version = '2.0';
# 	window.fbq.queue = [];
# 	window.fbq('init', '593656132426244');
# 	window.fbq('track', 'PageView');
#   </script>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="finanzen.net" name="apple-mobile-web-app-title"/>
#   <meta content="https://www.finanzen.net/index/dax" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="finanzen.net" property="og:site_name"/>
#   <meta content="https://c.finanzen.net/cst/FinanzenNetStyleguide/chart.aspx?instruments=1,998032,830,814&amp;style=mountain_oneyear&amp;period=OneYear&amp;timezone=W. Europe Standard Time" property="og:image"/>
#   <meta content="1091065066" property="fb:admins"/>
#   <meta content="100000899021671" property="fb:admins"/>
#   <meta content="100002492112838" property="fb:admins"/>
#   <meta content="858200894215708" property="fb:app_id"/>
#   <meta content="205286226664" property="fb:pages"/>
#   <meta content="app-id=291973577, affiliate-data=ct=smartbanner&amp;pt=507228" name="apple-itunes-app"/>
#   <link href="https://images.finanzen.net/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://images.finanzen.net/images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://images.finanzen.net/favicon.ico" rel="shortcut icon"/>
#   <link color="#da532c" href="https://images.finanzen.net/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="https://images.finanzen.net/browserconfig.xml" name="msapplication-config"/>
#   <meta content="https://images.finanzen.net/images/favicon/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="finanzen.net GmbH" name="application-name"/>
#   <link href="/rss/news" rel="alternate" title="finanzen.net - News" type="application/rss+xml"/>
#   <link href="/rss/analysen" rel="alternate" title="finanzen.net - Analysen" type="application/rss+xml"/>
#   <link href="/opensearch/finanzen.xml" rel="search" title="finanzen.net" type="application/opensearchdescription+xml"/>
#   <link as="style" href="https://styles.finanzen.net/Content/Styles/styleguide/fin.min.css?v=e7624e4a" rel="preload">
#    <link href="https://styles.finanzen.net/Content/Styles/styleguide/fin.min.css?v=e7624e4a" rel="stylesheet">
#     <link as="style" href="https://styles.finanzen.net/Content/Styles/styleguide/mobile.min.css?v=e7624e4a" rel="preload">
#      <link href="https://styles.finanzen.net/Content/Styles/styleguide/mobile.min.css?v=e7624e4a" media="(max-width:991px)" rel="stylesheet">
#       <link as="style" href="https://styles.finanzen.net/Content/Styles/styleguide/desktop.min.css?v=e7624e4a" rel="preload">
#        <link href="https://styles.finanzen.net/Content/Styles/styleguide/desktop.min.css?v=e7624e4a" media="(min-width:768px)" rel="stylesheet">
#         <link as="style" href="https://styles.finanzen.net/Content/Styles/dist/style-net-core.css?v=e7624e4a" rel="preload">
#          <link href="https://styles.finanzen.net/Content/Styles/dist/style-net-core.css?v=e7624e4a" rel="stylesheet">
#           <link as="style" href="https://styles.finanzen.net/Content/Styles/dist/style-net-modifier.css?v=e7624e4a" rel="preload">
#            <link href="https://styles.finanzen.net/Content/Styles/dist/style-net-modifier.css?v=e7624e4a" rel="stylesheet">
#             <link as="style" href="https://styles.finanzen.net/Content/Styles/dist/style-net-component.css?v=e7624e4a" rel="preload">
#              <link href="https://styles.finanzen.net/Content/Styles/dist/style-net-component.css?v=e7624e4a" rel="stylesheet">
#               <link as="style" href="https://styles.finanzen.net/Content/Styles/styleguide/polyfill.css?v=e7624e4a" rel="preload">
#                <link href="https://styles.finanzen.net/Content/Styles/styleguide/polyfill.css?v=e7624e4a" rel="stylesheet">
#                 <link as="style" href="https://styles.finanzen.net/Content/Styles/content/cnt-styleguide-indexes.css?v=e7624e4a" rel="preload">
#                  <link href="https://styles.finanzen.net/Content/Styles/content/cnt-styleguide-indexes.css?v=e7624e4a" rel="stylesheet">
#                   <link as="script" href="https://scripts.finanzen.net/Content/Scripts/styleguide/jquery.min.js?v=e7624e4a" rel="preload">
#                    <script src="https://scripts.finanzen.net/Content/Scripts/styleguide/jquery.min.js?v=e7624e4a">
#                    </script>
#                    <script>
#                     const geoipEndpoint = 'https://geoip.finanzen.net/json/';
#                    </script>
#                    <script async="async" src="https://scripts.finanzen.net/Content/Scripts/country-traffic-redirect.min.js?v=e7624e4a">
#                    </script>
#                    <link as="script" href="https://scripts.finanzen.net/Content/Scripts/styleguide/fin.min.js?v=e7624e4a" rel="preload">
#                     <script src="https://scripts.finanzen.net/Content/Scripts/styleguide/fin.min.js?v=e7624e4a">
#                     </script>
#                     <script async="async" src="https://scripts.finanzen.net/Content/Scripts/styleguide/fin-async.min.js?v=e7624e4a">
#                     </script>
#                     <script>
#                      navigator.sayswho = function () { var e, r = navigator.userAgent, i = r.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*(\d+)/i) || []; return /trident/i.test(i[1]) ? 'IE ' + ((e = /\brv[ :]+(\d+)/g.exec(r) || [])[1] || '') : 'Chrome' === i[1] && null != (e = r.match(/\b(OPR|Edge)\/(\d+)/)) ? e.slice(1).join(' ').replace('OPR', 'Opera') : (i = i[2] ? [i[1], i[2]] : [navigator.appName, navigator.appVersion, '-?'], null != (e = r.match(/version\/(\d+)/i)) && i.splice(1, 1, e[1]), i.join(' ')) }();
# 	window.articlemetadata = {
# 		type: 'static',
# 		assetid: '51628152AC9F9AB3C11ABF3137B6A92B',
# 		section: '_index_dax',
# 		segA: 'Indizes',
# 		segB: 'CPI',
# 		segC: navigator.sayswho
# 	};
#     !function(e,n){function t(e){return'object'==typeof e?JSON.parse(JSON.stringify(e)):e}e[n]=e[n]||{nlsQ:function(o,s,c){var a=e.document,r=a.createElement('script');r.async=1,r.src=('http:'===e.location.protocol?'http:':'https:')+'//cdn-gl.nmrodam.com/conf/'+o+'.js#name='+s+'&ns='+n;var i=a.getElementsByTagName('script')[0];return i.parentNode.insertBefore(r,i),e[n][s]=e[n][s]||{g:c||{},ggPM:function(o,c,a,r,i){e[n][s].q=e[n][s].q||[];try{var l=t([o,c,a,r,i]);e[n][s].q.push(l)}catch(e){console&&console.log&&console.log('Error: Cannot register event in Nielsen SDK queue.')}},trackEvent:function(o){e[n][s].te=e[n][s].te||[];try{var c=t(o);e[n][s].te.push(c)}catch(e){console&&console.log&&console.log('Error: Cannot register event in Nielsen SDK queue.')}}},e[n][s]}}}(window,'NOLBUNDLE');var nSdkInstance=NOLBUNDLE.nlsQ('P524AC7FF-94C5-4B2A-81D4-1DC8BA3593DB','nlsnInstance');nSdkInstance.ggPM('staticstart',window.articlemetadata);
#                     </script>
#                     <script defer="defer" src="https://scripts.finanzen.net/Content/Scripts/dist/script-net.js?v=e7624e4a">
#                     </script>
#                     <script async="async" src="https://scripts.finanzen.net/Content/Scripts/styleguide/polyfill.js?v=e7624e4a">
#                     </script>
#                     <script defer="defer" src="https://scripts.finanzen.net/Content/Scripts/user/user-cookie.js?v=e7624e4a">
#                     </script>
#                     <script async="async" src="https://scripts.finanzen.net/Content/Scripts/user/1PlusX/1PlusX-init.js?v=e7624e4a">
#                     </script>
#                     <script>
#                      (function (win, doc, style, timeout) {
# 		var STYLE_ID = 'at-body-style';
#
# 		function getParent() {
# 			return doc.getElementsByTagName('head')[0];
# 		}
#
# 		function addStyle(parent, id, def) {
# 			if (!parent) {
# 				return;
# 			}
#
# 			var style = doc.createElement('style');
# 			style.id = id;
# 			style.innerHTML = def;
# 			parent.appendChild(style);
# 		}
#
# 		function removeStyle(parent, id) {
# 			if (!parent) {
# 				return;
# 			}
#
# 			var style = doc.getElementById(id);
# 			if (!style) {
# 				return;
# 			}
# 			parent.removeChild(style);
# 		}
#
# 		addStyle(getParent(), STYLE_ID, style);
# 		setTimeout(function () {
# 			removeStyle(getParent(), STYLE_ID);
# 		}, timeout);
# 	}(window, document, "#ad-at-container {opacity: 0 !important}", 3000));
#                     </script>
#                     <script async="async" src="https://scripts.finanzen.net/Content/Scripts/user/adobeTarget/at.js?v=e7624e4a">
#                     </script>
#                     <link as="script" href="https://scripts.finanzen.net/Content/Scripts/cmp/cmp.min.js?v=e7624e4a" rel="preload">
#                      <script src="https://scripts.finanzen.net/Content/Scripts/cmp/cmp.min.js?v=e7624e4a">
#                      </script>
#                      <script async="async" src="https://scripts.finanzen.net/Content/Scripts/financeads-optout.min.js?v=e7624e4a">
#                      </script>
#                      <script type="application/ld+json">
#                       {
# 	"@context" : "http://schema.org",
# 	"@type" : "WebSite",
# 	"url" : "https://www.finanzen.net/",
# 	"potentialAction" : {
# 			"@type" : "SearchAction",
# 			"target" : "https://www.finanzen.net/suchergebnis.asp?strSuchString={search_term_string}&strKat=alles&cx=partner-pub-2471698288233937:67d99y-kq4q&ie=ISO-8859-1&cof=FORID:10&q={search_term_string}&sa=Suche#1490",
# 			"query-input" : "required name=search_term_string"
# 		}
# 	}
#                      </script>
#                      <script>
#                       utcTimeOffsetToApplication = 2;
#                      </script>
#                      <script>
#                       var fin_keywords = 'wkn=846900;isin=de0008469008;section=dax;country=c_d;hash1=$78ec905e;hash2=$78ec905e;hash3=$80915705;';
#                      </script>
#                      <script>
#                       var fin_rawCookieContent;
#
# 	if (typeof ($.cookie) == "function") {
# 		fin_rawCookieContent = $.cookie('fintargeting');
# 	}
#
# 	if (fin_rawCookieContent != null) {
#
# 		var fin_arrCookieContent;
# 		var fin_arrTargetingKeys;
# 		var fin_targetingKeyword;
#
# 		fin_arrCookieContent = fin_rawCookieContent.split('&');
# 		if (fin_arrCookieContent.length >= 2) {
#
# 			fin_targetingKeyword = fin_arrCookieContent[1].substring(fin_arrCookieContent[1].indexOf('=') + 1).replace('0x', '');
# 			fin_arrTargetingKeys = fin_targetingKeyword.split('').reverse();
#
# 			for (var i = 0; i < fin_arrTargetingKeys.length; i++) {
# 				if (fin_arrTargetingKeys[i] !== '0') {
# 					fin_keywords += 'Fin' + (i + 1) + '=' + fin_arrTargetingKeys[i] + ';';
# 				}
# 			}
# 		}
# 	}
#                      </script>
#                      <script id="finappnjs">
#                       var winW = window.innerWidth || window.document.documentElement.clientWidth || window.document.body.clientWidth;
# 			var asmiView = (((window.screen && screen.availWidth && (screen.availWidth < 768)) || winW < 768) && $.cookie('fin-classic-viewport') !== 'active=1') ? 'm' : 'd';
#
#
# 			if (asmiView === 'd') {
# 				adSSetup = {
#
# 					'view': asmiView
#
#
# 					, 'partners': true
#
#
# 					, 'adPlacements': ["mrec","billboard_btf","superbanner","sky","inpage"]
#
#
#
# 					, 'adSlotSizes': { "mrec":[{"minWidth": 1, "sizes": [[300,250],[300,600]]}],"billboard_btf":[{"minWidth": 1, "sizes": [[970,250],[800,250]]}],"superbanner":[{"minWidth": 1, "sizes": [[728,90],[728,600],[970,250],[800,250],[1000,600]]}],"sky":[{"minWidth": 1, "sizes": [[160,600],[120,600],[300,600],[500,1000],[1000,1000]]}],"inpage":[{"minWidth": 1, "sizes": [[1,1]]}] }
#
#
# 					, 'colorBg': true
#
# 					, 'bgClick': true
#
# 					, 'stickySky': true
#
#
#
# 					, 'isArticle': false
#
# 					, 'pageName': 'indizes_story'
# 					, 'target': fin_keywords
# 				};
# 			} else {
#
# 				adSSetup = {
#
# 					'view': asmiView
#
#
# 					, 'partners': true
#
#
# 					, 'adPlacements': ["mrec","mrec_btf","mrec_btf_4","banner","mrec_btf_3","inpage"]
#
#
#
# 					, 'adSlotSizes': { "mrec":[{"minWidth": 1, "sizes": [[300,250],[320,50],[320,75],[320,160]]}],"mrec_btf":[{"minWidth": 1, "sizes": [[300,250],[320,50],[320,75],[320,160],[300,300],[320,480],[1000,300]]}],"banner":[{"minWidth": 1, "sizes": [[320,160],[320,50],[320,75],[320,80]]}],"mrec_btf_3":[{"minWidth": 1, "sizes": [[300,250],[320,50],[320,75],[320,160]]}],"inpage":[{"minWidth": 1, "sizes": [[1,1]]}] }
#
#
# 					, 'colorBg': true
#
# 					, 'bgClick': true
#
# 					, 'stickySky': true
#
#
#
# 					, 'isArticle': false
#
# 					, 'pageName': 'indizes_story'
# 					, 'target': fin_keywords
# 				};
# 			}
#                      </script>
#                      <script async="" src="https://www.asadcdn.com/adlib/pages/finanzen.js">
#                      </script>
#                      <script>
#                       window.adHandler = window.adHandler || { cmd: [] };
# window.adPage = 'indizes_story';
#
# 		adHandler.cmd.push(function () {
# 			adHandler.service.setTargeting('Key-Value1', 'Value');
# 			adHandler.service.setTargeting('Key-Value2', ['Value1', 'Value2']);
# 			adHandler['mapping_' + window.adPage]();
# 			adHandler.service.request();
# 		});
#                      </script>
#                      <script async="async" src="https://scripts.finanzen.net/Content/Scripts/cpg_ads.min.js?v=e7624e4a">
#                      </script>
#                      <link as="script" href="https://data-fdbbf15b66.finanzen.net/iomm/latest/manager/base/es6/bundle.js" id="IOMmBundle" rel="preload"/>
#                      <link as="script" href="https://data-fdbbf15b66.finanzen.net/iomm/latest/bootstrap/loader.js" rel="preload"/>
#                      <script src="https://data-fdbbf15b66.finanzen.net/iomm/latest/bootstrap/loader.js">
#                      </script>
#                      <script>
#                       window.ivw = {
# 		initialized: false,
# 		enableMeasurement: true,
# 		enableParallelMeasurement : true,
# 		config: {
# 			enabled: true,
# 			site: 'finaonl',
# 			country: 'de',
# 			distributionChannel: 'web',
# 			debug: false,
# 			code: 'Sonstiges',
# 			codeAt: 'RedCont/Wirtschaft/AktienUndBoerse',
# 			codeCh: 'Boerse',
# 			comment: '',
# 			pixelType: 'cp'
# 		},
# 		init: function() {
#
# 			if (window.ivw.enableMeasurement && typeof window.IOMm !== 'undefined') {
# 				window.IOMm('configure', {
# 					st: window.ivw.config.site,
# 					dn: 'data-fdbbf15b66.finanzen.net',
# 					cn: window.ivw.config.country,
# 					dc: window.ivw.config.distributionChannel,
# 					dg: window.ivw.config.debug,
# 					mh: 5
# 				});
# 			}
#
# 			window.ivw.initialized = true;
# 		},
# 		countUp: function (code = null, comment = null) {
# 			window.agf.setAGFPixel(code);
# 			if (window.ivw.config.enabled) {
# 				if (!window.ivw.initialized) {
# 					window.ivw.init();
# 				}
#
# 				if (window.ivw.enableMeasurement && typeof window.IOMm !== 'undefined') {
# 					window.IOMm('pageview',
# 						{
# 							cp: window.ivw.buildCode(code),
# 							co: (comment === null) ? window.ivw.config.comment : comment,
# 							pt: window.ivw.config.pixelType
# 						});
# 				}
#
# 				if (window.ivw.enableParallelMeasurement) {
# 					var finUsrLoc = localStorage.getItem('finUsrLocCache');
# 					if (finUsrLoc) {
# 						window.ivw.countUp_ParallelMeasurement(finUsrLoc);
# 					} else {
# 						$.get('https://geoip.finanzen.net/json/', function(data) {
# 						if(data) {
# 							window.ivw.countUp_ParallelMeasurement(data.country_code);
# 						}
# 					});
# 					}
# 				}
# 			}
# 		},
# 		countUp_ParallelMeasurement: function (countryCode = null) {
# 			if (typeof countryCode === 'string' && window.ivw.enableParallelMeasurement) {
# 				if (countryCode.toLowerCase() === 'at' && typeof window.iom !== 'undefined') {
# 					var script = document.createElement('script');
# 					script.src = 'https://script-at.iocnt.net/iam.js';
# 					script.onload = function () {
# 						if (typeof window.iom !== 'undefined') {
# 							window.iom.c({
# 								cn: 'at',
# 								st: 'at_w_netfinanz',
# 								cp: window.ivw.buildCode(window.ivw.config.codeAt),
# 								sv: 'ke',
# 								ps: 'lin'
# 							}, 1);
# 						}
# 					};
# 					document.head.appendChild(script);
# 				} else if (countryCode.toLowerCase() === 'ch') {
# 					var img = document.createElement('img');
# 					img.src = 'https://finan-ssl.wemfbox.ch/cgi-bin/ivw/CP/' + window.ivw.buildCode(window.ivw.config.codeCh) + '?r=' + escape(document.referrer) + '&x=' + screen.width + 'x' + screen.height + '&d=' + (Math.random() * 100000);
# 					document.body.appendChild(img);
# 				}
# 			}
# 		},
# 		buildCode: function (code = null) {
# 			code = (typeof code !== 'string' || code.length === 0) ? window.ivw.config.code : code;
# 			if (code.length === 0) {
# 				code = 'UndefinedCode';
# 			}
# 			var intVpWidth = window.innerWidth;
# 			if (typeof (intVpWidth) != 'undefined' && !isNaN(intVpWidth) && intVpWidth < 768) {
# 				code = '135_' + code;
# 			}
# 			return code;
# 		}
# 	};
#
# 	window.agf = {
# 		setAGFPixel: function (strBereichName) {
# 			if (strBereichName != "" && strBereichName != null) {
# 				window.articlemetadata = {
# 					type: 'static',
# 					assetid: window.articlemetadata.assetid,
# 					section: window.articlemetadata.section,
# 					segA: strBereichName,
# 					segB: 'CPI',
# 					segC: window.articlemetadata.segC
# 				};
# 				nSdkInstance.ggPM('staticstart', window.articlemetadata);
# 			}
# 		}
# 	}
#                      </script>
#                      <script>
#                       window.__finnet = window.__finnet || {};
# 	window.__finnet.constants = {
# 		localStorageKey: 'finUsrLocCache'
# 	};
#
# 	window.__finnet.initBeacon = () => {
# 		window['_comscore'] = window['_comscore'] || [];
# 		window['_comscore'].push({
# 			c1: "2",
# 			c2: "34974286",
# 			ns_site: "www.finanzen.ch",
# 			mp_brand: "finanzen.ch"
# 		});
#
# 		var s = document.createElement("script");
# 		var el = document.getElementsByTagName("script")[0];
# 		s.async = true;
# 		s.src = "https://sb.scorecardresearch.com/beacon.js";
# 		el.parentNode.insertBefore(s, el);
# 	};
#
# 	var mptExist = window.location.href.indexOf("mpt=0") === -1;
# 	if (mptExist) {
# 		if (localStorage.getItem(window.__finnet.constants.localStorageKey) === null) {
# 			fetch('https://geoip.finanzen.net/json/').then(res => res.json())
# 				.then((data) => {
# 					if (data) {
# 						localStorage.setItem(window.__finnet.constants.localStorageKey, (data.country_code || '').toLowerCase());
# 					}
# 					return data;
# 				})
# 				.then(() => {
# 					if (localStorage.getItem(window.__finnet.constants.localStorageKey) === 'ch') {
# 						window.__finnet.initBeacon();
# 					}
# 				});
# 		} else {
# 			if (localStorage.getItem(window.__finnet.constants.localStorageKey) === 'ch') {
# 				window.__finnet.initBeacon();
# 			}
# 		}
# 	}
#                      </script>
#                      <script async="" src="https://gearwom.de/shared/scr">
#                      </script>
#                      <link href="https://www.finanzen.net/index/dax" rel="canonical"/>
#                     </link>
#                    </link>
#                   </link>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </link>
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="page-layout">
#   <img alt="" height="99999" src="data:image/svg+xml;base64,..." style="pointer-events: none; position: absolute; top: 0; left: 0; width: 97vw; height: 99vh; max-width: 99vw; max-height: 99vh;" width="99999"/>
#   <script>
#    if ('Indizes'.length > 0) {
# 		window.ivw.config.code = 'Indizes';
# 	}
# 	if (''.length > 0) {
# 		window.ivw.config.codeAt = '';
# 	}
# 	if (''.length > 0) {
# 		window.ivw.config.codeCh = '';
# 	}
# 	if ('s-index-DE0008469008----'.length > 0) {
# 		window.ivw.config.comment = 's-index-DE0008469008----';
# 	}
# 	window.ivw.init();
# 	window.ivw.countUp();
#   </script>
#   <!-- Google Tag Manager -->
#   <noscript>
#    <div>
#     <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TZL853" style="display: none; visibility: hidden" width="0">
#     </iframe>
#    </div>
#   </noscript>
#   <!-- End Google Tag Manager -->
#   <script>
#    var abp;
# abp = !(typeof adSSetup === 'object');
#   </script>
#   <script>
#    var navigationJSONConfig = {"activeItemIndex":"3"};
# 	navigationJSONConfig.username = objCookie.Benutzername;
# 	navigationJSONConfig.hasFinnetZeroLogin = isFinnetZeroLoginCookieActive();
#   </script>
#   <header class="page-header">
#    <div class="page-header__market">
#     <div class="quote-ticker">
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/index/dax">
#        DAX
#       </a>
#       <span class="quote-ticker__value">
#        15.856
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--negative">
#        -0,2%
#       </span>
#      </span>
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/index/euro_stoxx_50">
#        ESt50
#       </a>
#       <span class="quote-ticker__value">
#        4.395
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--negative">
#        -0,3%
#       </span>
#      </span>
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/index/tecdax">
#        TDax
#       </a>
#       <span class="quote-ticker__value">
#        3.293
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--positive">
#        +0,5%
#       </span>
#      </span>
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/index/dow_jones">
#        Dow
#       </a>
#       <span class="quote-ticker__value">
#        33.809
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--positive">
#        +0,1%
#       </span>
#      </span>
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/index/nasdaq_composite">
#        Nas
#       </a>
#       <span class="quote-ticker__value">
#        12.072
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--positive">
#        +0,1%
#       </span>
#      </span>
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/devisen/bitcoin-euro-kurs">
#        Bitcoin
#       </a>
#       <span class="quote-ticker__value">
#        24.886
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--negative">
#        -0,9%
#       </span>
#      </span>
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/devisen/dollarkurs">
#        Euro
#       </a>
#       <span class="quote-ticker__value">
#        1,0989
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--negative">
#        -1,0%
#       </span>
#      </span>
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/rohstoffe/oelpreis">
#        Öl
#       </a>
#       <span class="quote-ticker__value">
#        81,50
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--negative">
#        -0,3%
#       </span>
#      </span>
#      <span class="quote-ticker__item">
#       <a class="quote-ticker__label" href="/rohstoffe/goldpreis">
#        Gold
#       </a>
#       <span class="quote-ticker__value">
#        1.983
#       </span>
#       <span class="quote-ticker__value quote-ticker__value--positive">
#        +0,0%
#       </span>
#      </span>
#     </div>
#    </div>
#    <div class="page-header__navi-action" data-sg-page-header-navigation="main-menu" data-sg-side-panel-toggle="main-menu">
#     <span class="icon icon--menu">
#     </span>
#     <span class="icon icon--close">
#     </span>
#    </div>
#    <div class="page-header__logo">
#     <a class="page-header__logo-link" href="/" title="finanzen.net">
#      <span class="logo logo-finanzen-net">
#      </span>
#     </a>
#     <a class="page-header__logo-link display-none-sm" href="https://g.finanzen.net/zero-web-header-entdecke-zero" id="zero-web-header-entdecke-zero" rel="noopener" target="_blank" title="Online Broker">
#      <span class="logo logo-explore-zero">
#      </span>
#     </a>
#     <a class="page-header__logo-link display-none display-inline-flex-sm" href="https://g.finanzen.net/zero-mobile-header-entdecke-zero" id="zero-mobile-header-entdecke-zero" rel="noopener" target="_blank" title="Online Broker">
#      <span class="logo logo-explore-zero">
#      </span>
#     </a>
#    </div>
#    <div class="page-header__search">
#     <form action="/suchergebnis.asp" class="form-group form-group--icon form-group--page-header display-none-md" data-sg-tooltip-ref="suggest-search-desktop" method="GET" name="mmssearch">
#      <input autocomplete="off" class="input" data-sg-suggest-search-input="suggest-search-desktop" id="suggest-search-desktop-input" name="_search" placeholder="WKN/ISIN oder Name" type="text"/>
#      <button aria-label="Suche" class="form-group__icon icon icon--search" type="submit">
#      </button>
#     </form>
#     <div class="tooltip" data-sg-tooltip="" data-sg-tooltip-close-by="click-outside" data-sg-tooltip-id="suggest-search-desktop" data-sg-tooltip-open-by="event" data-sg-tooltip-placement="bottom-start" data-sg-tooltip-show-arrow="false">
#      <div class="suggest-search" data-sg-suggest-search="suggest-search-desktop">
#       <div class="suggest-search__top-ad">
#       </div>
#       <div class="suggest-search__template">
#        <div class="suggest-search__template-left">
#         <div class="suggest-search__popular-search">
#          <div class="suggest-search__headline">
#           Beliebte Suche
#          </div>
#          <span class="suggest-search__result suggest-search__result--no-identifier suggest-search__result--no-favorite">
#           <a class="suggest-search__result-link" href="/index/dax">
#            <span class="suggest-search__result-description">
#             DAX 40
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result suggest-search__result--no-identifier suggest-search__result--no-favorite">
#           <a class="suggest-search__result-link" href="/rohstoffe/oelpreis">
#            <span class="suggest-search__result-description">
#             Ölpreis
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result suggest-search__result--no-identifier suggest-search__result--no-favorite">
#           <a class="suggest-search__result-link" href="/devisen/dollarkurs">
#            <span class="suggest-search__result-description">
#             Euro - Dollar
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result suggest-search__result--no-identifier suggest-search__result--no-favorite">
#           <a class="suggest-search__result-link" href="/devisen/bitcoin-euro-kurs">
#            <span class="suggest-search__result-description">
#             Bitcoin - Euro
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result suggest-search__result--no-identifier suggest-search__result--no-favorite">
#           <a class="suggest-search__result-link" href="/rohstoffe/goldpreis">
#            <span class="suggest-search__result-description">
#             Goldpreis
#            </span>
#           </a>
#          </span>
#         </div>
#         <div class="suggest-search__most-wanted">
#          <div class="suggest-search__headline">
#           Meistgesucht
#          </div>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/tesla-aktie">
#            <span class="suggest-search__result-description">
#             Tesla
#            </span>
#            <span class="suggest-search__result-identifier">
#             A1CX3T
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=US88160R1014&amp;inTyp=1" rel="nofollow" title="Tesla zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/software-aktie">
#            <span class="suggest-search__result-description">
#             Software
#            </span>
#            <span class="suggest-search__result-identifier">
#             A2GS40
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE000A2GS401&amp;inTyp=1" rel="nofollow" title="Software zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/mercedes-benz-aktie">
#            <span class="suggest-search__result-description">
#             Mercedes-Benz Group (ex Daimler)
#            </span>
#            <span class="suggest-search__result-identifier">
#             710000
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE0007100000&amp;inTyp=1" rel="nofollow" title="Mercedes-Benz Group (ex Daimler) zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/basf-aktie">
#            <span class="suggest-search__result-description">
#             BASF
#            </span>
#            <span class="suggest-search__result-identifier">
#             BASF11
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE000BASF111&amp;inTyp=1" rel="nofollow" title="BASF zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/amazon-aktie">
#            <span class="suggest-search__result-description">
#             Amazon
#            </span>
#            <span class="suggest-search__result-identifier">
#             906866
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=US0231351067&amp;inTyp=1" rel="nofollow" title="Amazon zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/deutsche_bank-aktie">
#            <span class="suggest-search__result-description">
#             Deutsche Bank
#            </span>
#            <span class="suggest-search__result-identifier">
#             514000
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE0005140008&amp;inTyp=1" rel="nofollow" title="Deutsche Bank zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/volkswagen_vz-aktie">
#            <span class="suggest-search__result-description">
#             Volkswagen (VW) vz.
#            </span>
#            <span class="suggest-search__result-identifier">
#             766403
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE0007664039&amp;inTyp=1" rel="nofollow" title="Volkswagen (VW) vz. zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/tui-aktie">
#            <span class="suggest-search__result-description">
#             TUI
#            </span>
#            <span class="suggest-search__result-identifier">
#             TUAG50
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE000TUAG505&amp;inTyp=1" rel="nofollow" title="TUI zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/nel-aktie">
#            <span class="suggest-search__result-description">
#             NEL ASA
#            </span>
#            <span class="suggest-search__result-identifier">
#             A0B733
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=NO0010081235&amp;inTyp=1" rel="nofollow" title="NEL ASA zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/sap-aktie">
#            <span class="suggest-search__result-description">
#             SAP
#            </span>
#            <span class="suggest-search__result-identifier">
#             716460
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE0007164600&amp;inTyp=1" rel="nofollow" title="SAP zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/biontech-aktie">
#            <span class="suggest-search__result-description">
#             BioNTech (ADRs)
#            </span>
#            <span class="suggest-search__result-identifier">
#             A2PSR2
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=US09075V1026&amp;inTyp=1" rel="nofollow" title="BioNTech (ADRs) zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/allianz-aktie">
#            <span class="suggest-search__result-description">
#             Allianz
#            </span>
#            <span class="suggest-search__result-identifier">
#             840400
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE0008404005&amp;inTyp=1" rel="nofollow" title="Allianz zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/commerzbank-aktie">
#            <span class="suggest-search__result-description">
#             Commerzbank
#            </span>
#            <span class="suggest-search__result-identifier">
#             CBK100
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE000CBK1001&amp;inTyp=1" rel="nofollow" title="Commerzbank zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/rheinmetall-aktie">
#            <span class="suggest-search__result-description">
#             Rheinmetall
#            </span>
#            <span class="suggest-search__result-identifier">
#             703000
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE0007030009&amp;inTyp=1" rel="nofollow" title="Rheinmetall zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#          <span class="suggest-search__result">
#           <a class="suggest-search__result-link" href="/aktien/bayer-aktie">
#            <span class="suggest-search__result-description">
#             Bayer
#            </span>
#            <span class="suggest-search__result-identifier">
#             BAY001
#            </span>
#           </a>
#           <a class="suggest-search__result-favorite" href="/depot/watchlist.asp?isisin=DE000BAY0017&amp;inTyp=1" rel="nofollow" title="Bayer zur Watchlist hinzufügen">
#            <span class="icon icon--depot-add icon--scale-1500">
#            </span>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="suggest-search__template-right">
#         <div class="suggest-search__template-ad">
#          <div class="padding-1.00 border-thin border-radius-rounded border-color-gray-600">
#           <a class="display-block margin-bottom-1.00 font-align-center" href="https://g.finanzen.net/zero-web-finnet-suggestsearch-button">
#            Alle Aktien für
#            <strong>
#             0 Euro handeln
#            </strong>
#            mit finanzen.net zero.
#           </a>
#           <a class="button button--stretch button--zero" href="https://g.finanzen.net/zero-web-finnet-suggestsearch-button">
#            Hier informieren
#           </a>
#          </div>
#         </div>
#         <div class="suggest-search__news">
#          <div class="suggest-search__headline">
#           Heute im Fokus
#          </div>
#          <div class="news-layout">
#           <div class="news news--item-small">
#            <a class="news__card" href="/nachricht/aktien/heute-im-fokus-24-04-2023-12380785">
#             <time class="news__date" datetime="2023-04-24T10:40:27">
#              10:40 Uhr
#             </time>
#             <span class="news__kicker">
#              Heute im Fokus
#             </span>
#             <span class="news__title">
#              Nach ifo-Index: DAX leichter -- Asiens Börsen letztlich uneins -- Bed Bath &amp; Beyond hat Insolvenz nach Chapter 11angemeldet -- Silver Lake will Software AG übernehmen -- Salzgitter, Philips im Fokus
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="suggest-search__news">
#          <div class="suggest-search__headline">
#           Top News
#          </div>
#          <div class="news-layout">
#           <div class="news news--item-with-media-small">
#            <a class="news__card" href="/nachricht/trading/tradingtipps-fuer-ihr-depot-online-seminar-systematisch-trading-chancen-identifizieren-so-geht-es-an-den-maerkten-weiter-12383098">
#             <time class="news__date" datetime="2023-04-24T10:01:59">
#              10:37 Uhr
#             </time>
#             <span class="news__title">
#              Online-Seminar: Systematisch Trading-Chancen identifizieren - so geht es an den Märkten weiter!
#             </span>
#             <span class="news__media">
#              <img alt="" class="news__media-image" height="303" loading="lazy" src="https://images.finanzen.net/mediacenter/unsortiert/trading-charts-wachstum-khakimullin-aleksandr-shutterstock-660.jpg" title="Online-Seminar: Systematisch Trading-Chancen identifizieren - so geht es an den Märkten weiter!" width="660"/>
#             </span>
#            </a>
#           </div>
#           <div class="news news--item-with-media-small">
#            <a class="news__card" href="/nachricht/aktien/turnaround-nicht-erfolgreich-meme-aktie-bed-bath-beyond-ist-pleite-insolvenz-nach-chapter-11-angemeldet-bed-bath-beyond-aktie-rauscht-vorboerslich-an-der-nasdaq-ab-12383228">
#             <time class="news__date" datetime="2023-04-24T10:41:24">
#              10:35 Uhr
#             </time>
#             <span class="news__title">
#              Meme-Aktie Bed Bath &amp; Beyond ist pleite: Insolvenz nach Chapter 11 angemeldet - Bed Bath &amp; Beyond-Aktie rauscht vorbörslich an der NASDAQ ab
#             </span>
#             <span class="news__media">
#              <img alt="" class="news__media-image" height="303" loading="lazy" src="https://images.finanzen.net/mediacenter/unsortiert/bed_bath_beyond_sean_pavone_660.jpg" title="Meme-Aktie Bed Bath &amp; Beyond ist pleite: Insolvenz nach Chapter 11 angemeldet - Bed Bath &amp; Beyond-Aktie rauscht vorbörslich an der NASDAQ ab" width="660"/>
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="suggest-search__results" id="search">
#        <div class="suggest-search__result-group">
#         <div class="suggest-search__headline">
#          Suche...
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="page-header__actions">
#     <a aria-pressed="false" class="button button--scale-0875-md button--zero display-none display-inline-flex-sm display-none-xs" href="https://g.finanzen.net/zero-mobile-header-button" id="zero-mobile-header-button" rel="noopener" role="button" tabindex="0" target="_blank" title="finanzen.net zero">
#      1 Aktie gratis
#     </a>
#     <a aria-pressed="false" class="button button--scale-0875-md button--zero display-none display-inline-flex-xs" href="https://g.finanzen.net/zero-fnet_001f-header-button-depot" id="zero-mobile-header-button-xs" rel="noopener" role="button" tabindex="0" target="_blank" title="finanzen.net zero">
#      Depot
#     </a>
#     <a aria-pressed="false" class="button button--scale-0875-md button--zero background-color-white display-none" href="https://g.finanzen.net/zero-mobile-header-button-kunde" id="zero-mobile-header-button-kunde" role="button" tabindex="0">
#      <span class="logo logo-zero-icon font-size-x0.875 height-1-em" title="finanzen.net zero">
#      </span>
#      <span class="button__label font-color-brand-zero-magenta padding-start-0.50">
#       Trading
#      </span>
#     </a>
#     <a aria-pressed="false" class="button button--scale-0875-md button--zero display-none-sm" href="https://g.finanzen.net/zero-web-header-button" id="zero-web-header-button" rel="noopener" role="button" tabindex="0" target="_blank" title="finanzen.net zero">
#      1 Aktie gratis
#     </a>
# ...
#       </a>
#       <span class="page-footer__link hyperlink" onclick="javascript:_cmp_.showPM(); return false;">
#        Privatsphäre-Einstellungen
#       </span>
#      </div>
#     </div>
#     <div class="page-footer__social">
#      <div class="page-footer__header">
#       Folgen Sie uns auf
#      </div>
#      <div class="page-footer__social-button">
#       <a class="button button--pill button--flat border-color-brand-facebook" href="https://www.facebook.com/finanzen.net" rel="noopener" target="_blank" title="finanzen.net bei Facebook">
#        <span class="icon icon--social-media-facebook font-color-brand-facebook">
#        </span>
#       </a>
#       <a class="button button--pill button--flat border-color-brand-youtube" href="https://www.youtube.com/channel/UC0SfuDptovS05L3JjXSHjBg" rel="noopener" target="_blank" title="finanzen.net bei Youtube">
#        <span class="icon icon--social-media-youtube font-color-brand-youtube">
#        </span>
#       </a>
#       <a class="button button--pill button--flat border-color-brand-linkedin" href="https://de.linkedin.com/company/finanzen-net" rel="noopener" target="_blank" title="finanzen.net bei LinkedIn">
#        <span class="icon icon icon--social-media-linkedin font-color-brand-linkedin">
#        </span>
#       </a>
#       <a class="button button--pill button--flat border-color-brand-xing" href="https://www.xing.com/pages/finanzen-netgmbh" rel="noopener" target="_blank" title="finanzen.net bei XING">
#        <span class="icon icon icon--social-media-xing font-color-brand-xing">
#        </span>
#       </a>
#       <a class="button button--pill button--flat border-color-brand-rss" href="/dienste/rss" title="finanzen.net RSS Feed">
#        <span class="icon icon--rss font-color-brand-rss">
#        </span>
#       </a>
#       <a class="button button--pill button--flat border-color-brand-twitter" href="https://twitter.com/FinanzenNet" rel="noopener" target="_blank" title="finanzen.net bei Twitter">
#        <span class="icon icon--social-media-twitter font-color-brand-twitter">
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="page-footer__apps">
#      <div class="page-footer__header">
#       Apps
#      </div>
#      <div class="page-footer__col">
#       <a class="page-footer__link" href="/apps">
#        finanzen.net App
#       </a>
#       <a class="page-footer__link" href="/waehrungsrechner">
#        Währungsrechner
#       </a>
#       <a class="page-footer__link" href="/zero/apps/">
#        Broker App
#       </a>
#      </div>
#     </div>
#     <div class="page-footer__app-store">
#      <div class="page-footer__header font-color-transparent">
#       iOS &amp; Android
#      </div>
#      <div class="page-footer__col">
#       <a class="page-footer__apps-badge" href="https://itunes.apple.com/de/app/b%C3%B6rse-aktien-finanzen-net/id291973577?pt=507228&amp;ct=finanzen.net%2Ffooter&amp;mt=8" rel="noopener" target="_blank">
#        <noscript class="loading-lazy">
#         <img alt="finanzen.net iOS App" class="logo logo-apple-store" loading="lazy" src="https://images.finanzen.net/images/assets/apple-store-badge.svg"/>
#        </noscript>
#       </a>
#       <a class="page-footer__apps-badge" href="https://play.google.com/store/apps/details?id=de.finanzen.net" rel="noopener" target="_blank">
#        <noscript class="loading-lazy">
#         <img alt="finanzen.net Android App" class="logo logo-google-play-store" loading="lazy" src="https://images.finanzen.net/images/assets/google-play-badge.svg"/>
#        </noscript>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="page-footer__second-row">
#     <div class="page-footer__quick">
#      <div class="page-footer__header">
#       Aktien Prime Standard
#      </div>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/alle">
#       Alle
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/0-9">
#       0-9
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/a">
#       A
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/b">
#       B
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/c">
#       C
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/d">
#       D
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/e">
#       E
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/f">
#       F
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/g">
#       G
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/h">
#       H
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/i">
#       I
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/j">
#       J
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/k">
#       K
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/l">
#       L
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/m">
#       M
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/n">
#       N
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/o">
#       O
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/p">
#       P
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/q">
#       Q
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/r">
#       R
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/s">
#       S
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/t">
#       T
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/u">
#       U
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/v">
#       V
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/w">
#       W
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/x">
#       X
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/y">
#       Y
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/primestandard/z">
#       Z
#      </a>
#      <a class="page-footer__quick-link" href="/index/dax/40-werte">
#       DAX
#      </a>
#      <a class="page-footer__quick-link" href="/index/mdax/werte">
#       MDAX
#      </a>
#      <a class="page-footer__quick-link" href="/index/dow_jones/werte">
#       Dow Jones
#      </a>
#      <a class="page-footer__quick-link" href="/index/euro_stoxx_50/werte">
#       EuroStoxx
#      </a>
#     </div>
#     <div class="page-footer__quick">
#      <div class="page-footer__header">
#       Quick Links
#      </div>
#      <a class="page-footer__quick-link" href="/news/">
#       News
#      </a>
#      <a class="page-footer__quick-link" href="/aktien/dax-realtimekurse">
#       Kurslisten
#      </a>
#      <a class="page-footer__quick-link" href="/analysen">
#       Analysen
#      </a>
#      <a class="page-footer__quick-link" href="/devisen">
#       Devisen
#      </a>
#      <a class="page-footer__quick-link" href="/devisen/dollarkurs">
#       Dollarkurs
#      </a>
#      <a class="page-footer__quick-link" href="/fonds">
#       Fonds
#      </a>
#      <a class="page-footer__quick-link" href="/zertifikate">
#       Zertifikate
#      </a>
#      <a class="page-footer__quick-link" href="/hebelprodukte">
#       Optionsscheine
#      </a>
#      <a class="page-footer__quick-link" href="/hebelprodukte">
#       Knock-Outs
#      </a>
#      <a class="page-footer__quick-link" href="/anleihen">
#       Anleihen
#      </a>
#      <a class="page-footer__quick-link" href="/rohstoffe">
#       Rohstoffe
#      </a>
#      <a class="page-footer__quick-link" href="/themen">
#       Themen
#      </a>
#      <a class="page-footer__quick-link" href="/ratgeber/wertpapiere/aktien-kaufen">
#       Aktien kaufen
#      </a>
#      <a class="page-footer__quick-link" href="/ratgeber/wertpapiere/online-depot-eroeffnen">
#       Depot eröffnen
#      </a>
#      <a class="page-footer__quick-link" href="/profiluebersicht">
#       Portfolio
#      </a>
#      <a class="page-footer__quick-link" href="/index/shanghai_composite">
#       Aktien China
#      </a>
#      <a class="page-footer__quick-link" href="/waehrungsrechner">
#       Währungsrechner
#      </a>
#      <a class="page-footer__quick-link" href="/ratgeber/gold-kaufen">
#       Gold kaufen
#      </a>
#      <a class="page-footer__quick-link" href="/ratgeber/kryptowaehrung/bitcoin-kaufen">
#       Bitcoin kaufen
#      </a>
#      <a class="page-footer__quick-link" href="/ratgeber/kryptowaehrung/ethereum-kaufen">
#       Ethereum kaufen
#      </a>
#      <a class="page-footer__quick-link" href="/cfd">
#       CFD
#      </a>
#      <a class="page-footer__quick-link" href="/aktienkurse">
#       Aktienkurse
#      </a>
#      <a class="page-footer__quick-link" href="/rohstoffe/oelpreis">
#       Ölpreis
#      </a>
#      <a class="page-footer__quick-link" href="/zinsen/leitzins">
#       Leitzins
#      </a>
#      <a class="page-footer__quick-link" href="/ipo/">
#       IPO
#      </a>
#      <a class="page-footer__quick-link" href="/boersenkurse">
#       Börsenkurse
#      </a>
#      <a class="page-footer__quick-link" href="/lexikon/boersenlexikon/">
#       Lexikon
#      </a>
#      <a class="page-footer__quick-link" href="/apps">
#       Börse App
#      </a>
#      <a class="page-footer__quick-link" href="https://tradingdesk.de" rel="noopener" target="_blank">
#       Trading-Desk
#      </a>
#      <a class="page-footer__quick-link" href="/ratgeber/wertpapiere/etf-sparplan">
#       ETF-Sparplan
#      </a>
#      <a class="page-footer__quick-link" href="/ratgeber/vermoegenswirksame-leistungen">
#       Vermögenswirksame Leistungen
#      </a>
#      <a class="page-footer__quick-link" href="/zero/">
#       Online Broker
#      </a>
#      <a class="page-footer__quick-link" href="/ratgeber/unternehmen/">
#       Top Unternehmen
#      </a>
#     </div>
#    </div>
#    <div id="bafin-hint">
#    </div>
#    <div id="p500-hint">
#    </div>
#    <div class="page-footer__third-row">
#     <div class="page-footer__copyright">
#      Für die aufgeführten Inhalte kann keine Gewährleistung für die Vollständigkeit, Richtigkeit und Genauigkeit übernommen werden.
#
# 			Kursinformationen von SIX Financial Information. Verzögerung Deutsche Börse: 15 Min., Nasdaq, NYSE: 20 Min. © 1999-2023 finanzen.net GmbH
#     </div>
#    </div>
#   </footer>
#   <div class="page-layout__ad-footer-top margin-top-2.00">
#    <div id="footer-ad">
#     <div class="font-align-center" id="cpg_footer">
#     </div>
#    </div>
#   </div>
#   <div class="page-layout__ad-footer-bottom">
#    <div class="ad">
#    </div>
#   </div>
#   <div class="page-layout__ad-header-top">
#    <div class="ad">
#     <div id="sticky-anchor-superbanner">
#     </div>
#     <div class="sticky-height-prefix" id="sticky-superbanner">
#      <div id="superbanner">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="page-layout__ad-header-bottom">
#    <div class="ad">
#    </div>
#   </div>
#   <div class="page-layout__ad-left">
#    <div class="ad">
#    </div>
#   </div>
#   <div class="page-layout__ad-right">
#    <div class="ad">
#     <div id="sticky-anchor-sky">
#     </div>
#     <div id="sticky-sky">
#      <div id="sky">
#      </div>
#     </div>
#    </div>
#   </div>
#   <button aria-label="Back-to-Top Button" class="back-to-top button button--primary button--icon button--pill button--scale-1250" data-sg-back-to-top-parent=".page-content">
#    <span class="icon icon--arrow-up-2">
#    </span>
#   </button>
#   <div id="inpage">
#   </div>
#   <script>
#    var activateStickyAds = false;
#
#
# 		if (asmiView === "m") {
# 			var bs_wrapper = $('.bs-wrapper').html();
# 			$('.bs-wrapper').remove();
# 			$('.bs-wrapper--mobile').html(bs_wrapper);
# 			$('#superbanner').attr("id", "banner");
# 			$('#sky').attr("id", "mrec_btf_3");
# 			$('#mrec_btf').attr("id", "mrec_btf_2");
# 			if ($('#m_mrec_btf').length > 0) {
# 				$('#m_mrec_btf').attr("id", "mrec_btf");
# 			} else {
# 				$('#mrec').attr("id", "mrec_btf");
# 			}
# 			if ($('#m_mrec').length > 0) {
# 				$('#m_mrec').attr("id", "mrec");
# 			} else {
# 				$('#billboard').attr("id", "mrec");
# 			}
# 			if ($('#m_billboard_btf_2').length > 0) {
# 				$('#m_billboard_btf_2').attr("id", "mrec_btf_5");
# 			} else {
# 				$('#billboard_btf_2').attr("id", "mrec_btf_5");
# 			}
# 			$('#billboard_btf').attr("id", "mrec_btf_4");
# 		} else {
# 			$('#d_mrec').attr("id", "mrec");
# 			$('#d_billboard_btf_2').attr("id", "billboard_btf_2");
# 		}
#
#
# 		//ASMI LoadHandler
# 		if (activateStickyAds) {
# 			sas_loadHandler = function(adSlot) {
#
# 				if (window.innerWidth >= 768) {
#
#
# 					if (adSlot.hasAd && adSlot.id === 'mrec') {
#
# 						$(window).scroll(sticky_relocate_mrec);
# 						sticky_relocate_mrec();
# 						var timermrec = null, interval = 1000, value = 0;
# 						if (timermrec !== null) return;
# 						timermrec = setInterval(function() {
# 							value++;
# 							if (value > 2) {
# 								$('#sticky-mrec').removeClass('stick');
# 								$('#sticky-mrec').attr('id', '');
# 								$('#sticky-mrec').css('width', 'initial');
# 								$('#sticky-anchor-mrec').height(0);
# 								clearInterval(timermrec );
# 								sticky_relocate_mrec  = function () { return null };
# 							}
# 						}, interval);
# 					}
# 				}
#
#
# 				if (adSlot.hasAd && adSlot.id === 'superbanner' || adSlot.hasAd && adSlot.id === 'banner') {
#
# 					$(window).scroll(sticky_relocate_superbanner);
# 					sticky_relocate_superbanner();
# 					var timersuperbanner = null, interval = 1000, value = 0;
# 					var timer_value = 1;
# 					if (window.innerWidth < 768) timer_value = 2;
# 					if (timersuperbanner !== null) return;
# 					timersuperbanner = setInterval(function() {
# 						value++;
# 						if (value > timer_value) {
# 							if ($('#sticky-superbanner').hasClass('stick')) {
# 								$('#sticky-superbanner').slideUp("slow", function () {
# 									$('#sticky-superbanner').slideDown(1, function () { });
# 									window.IsTimeOver = true;
# 									$('#sticky-superbanner').removeClass('stick');
# 									$('#sticky-superbanner').css('margin-top', '0');
# 								});
# 							}
#
# 							window.IsTimeOver = true;
# 							clearInterval(timersuperbanner);
# 							sticky_relocate_superbanner = function () { return null };
# 						}
# 					}, interval);
# 				}
# 			};
# 		}
#   </script>
#   <script>
#    var isDesktopView = true;
# 		var maxMobileWidth = 992;
#
# 		$(document).ready(function () {
# 			if ($(window).width() < maxMobileWidth) {
# 				moveToPosition('xs');
# 				isDesktopView = false;
# 			}
# 		});
#
# 		$(window).resize(function () {
# 			if (isDesktopView && $(window).width() < maxMobileWidth) {
# 				moveToPosition('xs');
# 				isDesktopView = false;
# 			} else if (!isDesktopView && $(window).width() >= maxMobileWidth) {
# 				moveToPosition('lg');
# 				isDesktopView = true;
# 			}
# 		});
#
# 		function moveToPosition(pos) {
# 			$('.responsivePosition').each(function () {
# 				$("#" + pos + "Position" + this.id).html($(this));
# 			});
# 		}
#   </script>
#   <div class="display_none display-none">
#    <script>
#     /* <![CDATA[ */
# 		var google_conversion_id = 1061761171;
# 		var google_custom_params = window.google_tag_params;
# 		var google_remarketing_only = true;
#
# 		/* ]]> */
#    </script>
#    <script class="cmp-script" data-cmp-purpose="social" data-cmp-type="googleAdvertisingProducts" type="text/html">
#     PHNjcmlwdCBzcmM9Ii8vd3d3Lmdvb2dsZWFkc2VydmljZXMuY29tL3BhZ2VhZC9jb252ZXJzaW9uLmpzIj48L3NjcmlwdD4=
#    </script>
#    <noscript>
#     <div style="display:inline;">
#      <script class="cmp-image" data-cmp-purpose="social" data-cmp-type="googleAdvertisingProducts" type="text/html">
#       PGltZyBoZWlnaHQ9IjEiIHdpZHRoPSIxIiBzdHlsZT0iYm9yZGVyLXN0eWxlOm5vbmU7IiBhbHQ9IiIgc3JjPSIvL2dvb2dsZWFkcy5nLmRvdWJsZWNsaWNrLm5ldC9wYWdlYWQvdmlld3Rocm91Z2hjb252ZXJzaW9uLzEwNjE3NjExNzEvP3ZhbHVlPTAmYW1wO2d1aWQ9T04mYW1wO3NjcmlwdD0wIj4=
#      </script>
#     </div>
#    </noscript>
#   </div>
#   <script>
#    var currentRoute = 'Markets/Indices/Details';
# 		var webPushSettings = {
# 			firebaseTopic: "news-push-web",
# 			isTestRun: false
#
# 		}
#   </script>
#   <script async="async" src="https://scripts.finanzen.net/Content/Scripts/web-push/init.min.js?v=e7624e4a">
#   </script>
#   <!--id:b1-finnet4-->
#  </body>
# </html>
